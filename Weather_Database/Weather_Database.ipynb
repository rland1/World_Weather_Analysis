# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import gmaps
from datetime import datetime
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ea586a92e1fbdf7e55a991b862de0737

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | gamba
# Processing Record 2 of Set 1 | san patricio
# Processing Record 3 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | cape town
# Processing Record 6 of Set 1 | zhanakorgan
# Processing Record 7 of Set 1 | waddan
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | altamira
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | ribeira grande
# Processing Record 13 of Set 1 | san javier
# Processing Record 14 of Set 1 | manta
# Processing Record 15 of Set 1 | havre-saint-pierre
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | vilyuysk
# Processing Record 18 of Set 1 | kavieng
# Processing Record 19 of Set 1 | walvis bay
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | port elizabeth
# Processing Record 22 of Set 1 | khani
# Processing Record 23 of Set 1 | cidreira
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | klaksvik
# Processing Record 26 of Set 1 | ahipara
# Processing Record 27 of Set 1 | samarai
# Processing Record 28 of Set 1 | biak
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | cherskiy
# Processing Record 31 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 1 | fethiye
# Processing Record 33 of Set 1 | avarua
# Processing Record 34 of Set 1 | makakilo city
# Processing Record 35 of Set 1 | mehamn
# Processing Record 36 of Set 1 | tual
# Processing Record 37 of Set 1 | saskylakh
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | yellowknife
# Processing Record 40 of Set 1 | yeppoon
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | phayao
# Processing Record 45 of Set 1 | katghora
# Processing Record 46 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 1 | praia
# Processing Record 48 of Set 1 | male
# Processing Record 49 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 50 of Set 1 | carutapera
# Processing Record 1 of Set 2 | urengoy
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | bull savanna
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | manavgat
# Processing Record 6 of Set 2 | porto novo
# Processing Record 7 of Set 2 | dingle
# Processing Record 8 of Set 2 | lompoc
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | yugorsk
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | hanchuan
# Processing Record 14 of Set 2 | mataura
# Processing Record 15 of Set 2 | riacho de santana
# Processing Record 16 of Set 2 | baruun-urt
# Processing Record 17 of Set 2 | narsaq
# Processing Record 18 of Set 2 | xining
# Processing Record 19 of Set 2 | luderitz
# Processing Record 20 of Set 2 | guiset
# City not found. Skipping...
# Processing Record 21 of Set 2 | pevek
# Processing Record 22 of Set 2 | shakhovskaya
# Processing Record 23 of Set 2 | wum
# Processing Record 24 of Set 2 | saint-fabien
# City not found. Skipping...
# Processing Record 25 of Set 2 | castro
# Processing Record 26 of Set 2 | jamestown
# Processing Record 27 of Set 2 | longyearbyen
# Processing Record 28 of Set 2 | tasiilaq
# Processing Record 29 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 30 of Set 2 | butaritari
# Processing Record 31 of Set 2 | esperance
# Processing Record 32 of Set 2 | palauig
# Processing Record 33 of Set 2 | kupang
# Processing Record 34 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 2 | riberalta
# Processing Record 36 of Set 2 | nuuk
# Processing Record 37 of Set 2 | yar-sale
# Processing Record 38 of Set 2 | sabla
# Processing Record 39 of Set 2 | urubicha
# Processing Record 40 of Set 2 | mackenzie
# Processing Record 41 of Set 2 | meulaboh
# Processing Record 42 of Set 2 | sabya
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | hengshui
# Processing Record 45 of Set 2 | havelock
# Processing Record 46 of Set 2 | pareora
# Processing Record 47 of Set 2 | vao
# Processing Record 48 of Set 2 | sinjar
# Processing Record 49 of Set 2 | mount darwin
# Processing Record 50 of Set 2 | worland
# Processing Record 1 of Set 3 | solano
# Processing Record 2 of Set 3 | gizo
# Processing Record 3 of Set 3 | sioux lookout
# Processing Record 4 of Set 3 | baracoa
# Processing Record 5 of Set 3 | qaanaaq
# Processing Record 6 of Set 3 | tupaciguara
# Processing Record 7 of Set 3 | busselton
# Processing Record 8 of Set 3 | glubokiy
# Processing Record 9 of Set 3 | umkomaas
# Processing Record 10 of Set 3 | viamao
# Processing Record 11 of Set 3 | robertsport
# Processing Record 12 of Set 3 | nikolsk
# Processing Record 13 of Set 3 | nisia floresta
# Processing Record 14 of Set 3 | ekibastuz
# Processing Record 15 of Set 3 | buraydah
# Processing Record 16 of Set 3 | saldanha
# Processing Record 17 of Set 3 | tura
# Processing Record 18 of Set 3 | sambava
# Processing Record 19 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 20 of Set 3 | kaoma
# Processing Record 21 of Set 3 | san isidro
# Processing Record 22 of Set 3 | tessalit
# Processing Record 23 of Set 3 | souillac
# Processing Record 24 of Set 3 | codrington
# Processing Record 25 of Set 3 | kargasok
# Processing Record 26 of Set 3 | constitucion
# Processing Record 27 of Set 3 | talara
# Processing Record 28 of Set 3 | syracuse
# Processing Record 29 of Set 3 | kalmunai
# Processing Record 30 of Set 3 | ilulissat
# Processing Record 31 of Set 3 | nikolskoye
# Processing Record 32 of Set 3 | fortuna
# Processing Record 33 of Set 3 | salinas
# Processing Record 34 of Set 3 | kisangani
# Processing Record 35 of Set 3 | hilo
# Processing Record 36 of Set 3 | hermanus
# Processing Record 37 of Set 3 | bluff
# Processing Record 38 of Set 3 | whitehorse
# Processing Record 39 of Set 3 | fort-shevchenko
# Processing Record 40 of Set 3 | port blair
# Processing Record 41 of Set 3 | mar del plata
# Processing Record 42 of Set 3 | portland
# Processing Record 43 of Set 3 | nyurba
# Processing Record 44 of Set 3 | balkanabat
# Processing Record 45 of Set 3 | chipinge
# Processing Record 46 of Set 3 | lososina
# Processing Record 47 of Set 3 | iqaluit
# Processing Record 48 of Set 3 | bambous virieux
# Processing Record 49 of Set 3 | qena
# Processing Record 50 of Set 3 | mollendo
# Processing Record 1 of Set 4 | mount gambier
# Processing Record 2 of Set 4 | albany
# Processing Record 3 of Set 4 | upernavik
# Processing Record 4 of Set 4 | vaini
# Processing Record 5 of Set 4 | durant
# Processing Record 6 of Set 4 | arawa
# Processing Record 7 of Set 4 | victoria
# Processing Record 8 of Set 4 | ponta do sol
# Processing Record 9 of Set 4 | jamame
# Processing Record 10 of Set 4 | bethel
# Processing Record 11 of Set 4 | ola
# Processing Record 12 of Set 4 | kirakira
# Processing Record 13 of Set 4 | kaitangata
# Processing Record 14 of Set 4 | sur
# Processing Record 15 of Set 4 | piacabucu
# Processing Record 16 of Set 4 | lobito
# Processing Record 17 of Set 4 | saint george
# Processing Record 18 of Set 4 | kodiak
# Processing Record 19 of Set 4 | jardim
# Processing Record 20 of Set 4 | east london
# Processing Record 21 of Set 4 | new norfolk
# Processing Record 22 of Set 4 | north bend
# Processing Record 23 of Set 4 | redlands
# Processing Record 24 of Set 4 | poum
# Processing Record 25 of Set 4 | vire
# Processing Record 26 of Set 4 | chemin grenier
# Processing Record 27 of Set 4 | ucluelet
# Processing Record 28 of Set 4 | dahuk
# Processing Record 29 of Set 4 | aktau
# Processing Record 30 of Set 4 | saint-philippe
# Processing Record 31 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 4 | santa rosa
# Processing Record 33 of Set 4 | bud
# Processing Record 34 of Set 4 | beyneu
# Processing Record 35 of Set 4 | cabo san lucas
# Processing Record 36 of Set 4 | launceston
# Processing Record 37 of Set 4 | ancud
# Processing Record 38 of Set 4 | leningradskiy
# Processing Record 39 of Set 4 | ballina
# Processing Record 40 of Set 4 | lima
# Processing Record 41 of Set 4 | olinda
# Processing Record 42 of Set 4 | shieli
# Processing Record 43 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 4 | chilca
# Processing Record 45 of Set 4 | bend
# Processing Record 46 of Set 4 | aykhal
# Processing Record 47 of Set 4 | ridgecrest
# Processing Record 48 of Set 4 | belyy yar
# Processing Record 49 of Set 4 | saint-pierre
# Processing Record 50 of Set 4 | severo-kurilsk
# Processing Record 1 of Set 5 | sorland
# Processing Record 2 of Set 5 | rawson
# Processing Record 3 of Set 5 | beaverlodge
# Processing Record 4 of Set 5 | wairoa
# Processing Record 5 of Set 5 | tiksi
# Processing Record 6 of Set 5 | ergani
# Processing Record 7 of Set 5 | maputo
# Processing Record 8 of Set 5 | okhotsk
# Processing Record 9 of Set 5 | bengkulu
# Processing Record 10 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 5 | sycow
# Processing Record 12 of Set 5 | pangpang
# Processing Record 13 of Set 5 | hsinchu
# Processing Record 14 of Set 5 | bredasdorp
# Processing Record 15 of Set 5 | axim
# Processing Record 16 of Set 5 | torbay
# Processing Record 17 of Set 5 | pecos
# Processing Record 18 of Set 5 | tiffin
# Processing Record 19 of Set 5 | shablykino
# Processing Record 20 of Set 5 | usinsk
# Processing Record 21 of Set 5 | bathsheba
# Processing Record 22 of Set 5 | geraldton
# Processing Record 23 of Set 5 | avera
# Processing Record 24 of Set 5 | nanpiao
# Processing Record 25 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 26 of Set 5 | zhigansk
# Processing Record 27 of Set 5 | gunnedah
# Processing Record 28 of Set 5 | emerald
# Processing Record 29 of Set 5 | culpeper
# Processing Record 30 of Set 5 | semikarakorsk
# Processing Record 31 of Set 5 | norman wells
# Processing Record 32 of Set 5 | thompson
# Processing Record 33 of Set 5 | hasaki
# Processing Record 34 of Set 5 | lasa
# Processing Record 35 of Set 5 | washington
# Processing Record 36 of Set 5 | plettenberg bay
# Processing Record 37 of Set 5 | kahului
# Processing Record 38 of Set 5 | chumphon
# Processing Record 39 of Set 5 | hirado
# Processing Record 40 of Set 5 | chokurdakh
# Processing Record 41 of Set 5 | pakenham
# Processing Record 42 of Set 5 | tungkang
# City not found. Skipping...
# Processing Record 43 of Set 5 | horta
# Processing Record 44 of Set 5 | clyde river
# Processing Record 45 of Set 5 | mahebourg
# Processing Record 46 of Set 5 | port hedland
# Processing Record 47 of Set 5 | rocha
# Processing Record 48 of Set 5 | gat
# Processing Record 49 of Set 5 | bembereke
# Processing Record 50 of Set 5 | raymond
# Processing Record 1 of Set 6 | hamilton
# Processing Record 2 of Set 6 | moa
# Processing Record 3 of Set 6 | ternate
# Processing Record 4 of Set 6 | itacurubi de la cordillera
# Processing Record 5 of Set 6 | waingapu
# Processing Record 6 of Set 6 | lakes entrance
# Processing Record 7 of Set 6 | angol
# Processing Record 8 of Set 6 | dzhebariki-khaya
# Processing Record 9 of Set 6 | bom jesus
# Processing Record 10 of Set 6 | zalantun
# Processing Record 11 of Set 6 | gualeguaychu
# Processing Record 12 of Set 6 | arica
# Processing Record 13 of Set 6 | riyadh
# Processing Record 14 of Set 6 | alekseyevsk
# Processing Record 15 of Set 6 | ruatoria
# City not found. Skipping...
# Processing Record 16 of Set 6 | nanakuli
# Processing Record 17 of Set 6 | aguada de pasajeros
# Processing Record 18 of Set 6 | quatre cocos
# Processing Record 19 of Set 6 | carnarvon
# Processing Record 20 of Set 6 | watari
# Processing Record 21 of Set 6 | high level
# Processing Record 22 of Set 6 | izberbash
# Processing Record 23 of Set 6 | teneguiban
# City not found. Skipping...
# Processing Record 24 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 6 | palmer
# Processing Record 26 of Set 6 | pisco
# Processing Record 27 of Set 6 | bharatpur
# Processing Record 28 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 6 | dawlatabad
# Processing Record 30 of Set 6 | ostrovnoy
# Processing Record 31 of Set 6 | thunder bay
# Processing Record 32 of Set 6 | salalah
# Processing Record 33 of Set 6 | neryungri
# Processing Record 34 of Set 6 | pore
# Processing Record 35 of Set 6 | caravelas
# Processing Record 36 of Set 6 | taoudenni
# Processing Record 37 of Set 6 | grindavik
# Processing Record 38 of Set 6 | pervomayskoye
# Processing Record 39 of Set 6 | nishihara
# Processing Record 40 of Set 6 | morro bay
# Processing Record 41 of Set 6 | zaozerne
# Processing Record 42 of Set 6 | cockburn town
# Processing Record 43 of Set 6 | mitsamiouli
# Processing Record 44 of Set 6 | grand gaube
# Processing Record 45 of Set 6 | zaltan
# Processing Record 46 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 47 of Set 6 | newtownards
# Processing Record 48 of Set 6 | richards bay
# Processing Record 49 of Set 6 | nanortalik
# Processing Record 50 of Set 6 | viransehir
# Processing Record 1 of Set 7 | manati
# Processing Record 2 of Set 7 | yakeshi
# Processing Record 3 of Set 7 | wanlaweyn
# Processing Record 4 of Set 7 | troutdale
# Processing Record 5 of Set 7 | redmond
# Processing Record 6 of Set 7 | shingu
# Processing Record 7 of Set 7 | namibe
# Processing Record 8 of Set 7 | kaeo
# Processing Record 9 of Set 7 | lata
# Processing Record 10 of Set 7 | najran
# Processing Record 11 of Set 7 | armash
# Processing Record 12 of Set 7 | floro
# Processing Record 13 of Set 7 | ojinaga
# Processing Record 14 of Set 7 | luba
# Processing Record 15 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 7 | aswan
# Processing Record 17 of Set 7 | beringovskiy
# Processing Record 18 of Set 7 | sengiley
# Processing Record 19 of Set 7 | ayan
# Processing Record 20 of Set 7 | lahij
# Processing Record 21 of Set 7 | georgetown
# Processing Record 22 of Set 7 | mazagao
# Processing Record 23 of Set 7 | davlekanovo
# Processing Record 24 of Set 7 | ossora
# Processing Record 25 of Set 7 | bentiu
# Processing Record 26 of Set 7 | nouakchott
# Processing Record 27 of Set 7 | deputatskiy
# Processing Record 28 of Set 7 | atar
# Processing Record 29 of Set 7 | henties bay
# Processing Record 30 of Set 7 | wahiawa
# Processing Record 31 of Set 7 | faanui
# Processing Record 32 of Set 7 | general pico
# Processing Record 33 of Set 7 | carballo
# Processing Record 34 of Set 7 | tignere
# Processing Record 35 of Set 7 | ochamchira
# Processing Record 36 of Set 7 | coquimbo
# Processing Record 37 of Set 7 | paamiut
# Processing Record 38 of Set 7 | ardakan
# Processing Record 39 of Set 7 | dolores
# Processing Record 40 of Set 7 | moroni
# Processing Record 41 of Set 7 | jiuquan
# Processing Record 42 of Set 7 | gornozavodsk
# Processing Record 43 of Set 7 | hirara
# Processing Record 44 of Set 7 | arman
# Processing Record 45 of Set 7 | ordynskoye
# Processing Record 46 of Set 7 | ambon
# Processing Record 47 of Set 7 | rodrigues alves
# Processing Record 48 of Set 7 | tabas
# Processing Record 49 of Set 7 | yulara
# Processing Record 50 of Set 7 | metehara
# City not found. Skipping...
# Processing Record 1 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 2 of Set 8 | hihifo
# City not found. Skipping...
# Processing Record 3 of Set 8 | isangel
# Processing Record 4 of Set 8 | byron bay
# Processing Record 5 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 8 | euclides da cunha
# Processing Record 7 of Set 8 | granada
# Processing Record 8 of Set 8 | la fleche
# Processing Record 9 of Set 8 | parabel
# Processing Record 10 of Set 8 | wazirabad
# Processing Record 11 of Set 8 | duncan
# Processing Record 12 of Set 8 | susangerd
# Processing Record 13 of Set 8 | verkhoyansk
# Processing Record 14 of Set 8 | hambantota
# Processing Record 15 of Set 8 | siguiri
# Processing Record 16 of Set 8 | angoche
# Processing Record 17 of Set 8 | bambari
# Processing Record 18 of Set 8 | ormara
# Processing Record 19 of Set 8 | finspang
# Processing Record 20 of Set 8 | bonavista
# Processing Record 21 of Set 8 | mayo
# Processing Record 22 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 23 of Set 8 | sao joao da barra
# Processing Record 24 of Set 8 | kavaratti
# Processing Record 25 of Set 8 | pontes e lacerda
# Processing Record 26 of Set 8 | marrakesh
# Processing Record 27 of Set 8 | port hardy
# Processing Record 28 of Set 8 | port macquarie
# Processing Record 29 of Set 8 | wufeng
# Processing Record 30 of Set 8 | san cristobal
# Processing Record 31 of Set 8 | kanniyakumari
# Processing Record 32 of Set 8 | shenzhen
# Processing Record 33 of Set 8 | kruisfontein
# Processing Record 34 of Set 8 | qabis
# City not found. Skipping...
# Processing Record 35 of Set 8 | hailar
# Processing Record 36 of Set 8 | marienburg
# Processing Record 37 of Set 8 | vagay
# Processing Record 38 of Set 8 | nome
# Processing Record 39 of Set 8 | teya
# Processing Record 40 of Set 8 | san clemente
# Processing Record 41 of Set 8 | pavlodar
# Processing Record 42 of Set 8 | rio gallegos
# Processing Record 43 of Set 8 | bayonet point
# Processing Record 44 of Set 8 | haines junction
# Processing Record 45 of Set 8 | gatton
# Processing Record 46 of Set 8 | zaysan
# Processing Record 47 of Set 8 | provideniya
# Processing Record 48 of Set 8 | paucartambo
# City not found. Skipping...
# Processing Record 49 of Set 8 | ovca
# Processing Record 50 of Set 8 | brae
# Processing Record 1 of Set 9 | drayton valley
# Processing Record 2 of Set 9 | isabela
# Processing Record 3 of Set 9 | pesca
# Processing Record 4 of Set 9 | batemans bay
# Processing Record 5 of Set 9 | erenhot
# Processing Record 6 of Set 9 | alakurtti
# Processing Record 7 of Set 9 | athmallik
# Processing Record 8 of Set 9 | sisimiut
# Processing Record 9 of Set 9 | guerrero negro
# Processing Record 10 of Set 9 | maryborough
# Processing Record 11 of Set 9 | dogondoutchi
# Processing Record 12 of Set 9 | adrar
# Processing Record 13 of Set 9 | saint-augustin
# Processing Record 14 of Set 9 | san jose
# Processing Record 15 of Set 9 | winslow
# Processing Record 16 of Set 9 | serebryansk
# Processing Record 17 of Set 9 | tres arroyos
# Processing Record 18 of Set 9 | faya
# Processing Record 19 of Set 9 | clarksburg
# Processing Record 20 of Set 9 | kananga
# Processing Record 21 of Set 9 | coihueco
# Processing Record 22 of Set 9 | camacha
# Processing Record 23 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 24 of Set 9 | touros
# Processing Record 25 of Set 9 | tieli
# Processing Record 26 of Set 9 | port augusta
# Processing Record 27 of Set 9 | portales
# Processing Record 28 of Set 9 | half moon bay
# Processing Record 29 of Set 9 | baishishan
# Processing Record 30 of Set 9 | sobolevo
# Processing Record 31 of Set 9 | tulum
# Processing Record 32 of Set 9 | puro
# Processing Record 33 of Set 9 | kentau
# Processing Record 34 of Set 9 | biu
# Processing Record 35 of Set 9 | ondjiva
# Processing Record 36 of Set 9 | ayna
# Processing Record 37 of Set 9 | winburg
# Processing Record 38 of Set 9 | kalabo
# Processing Record 39 of Set 9 | margate
# Processing Record 40 of Set 9 | san rafael del sur
# Processing Record 41 of Set 9 | tororo
# Processing Record 42 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 9 | flinders
# Processing Record 44 of Set 9 | george town
# Processing Record 45 of Set 9 | coihaique
# Processing Record 46 of Set 9 | onega
# Processing Record 47 of Set 9 | sabha
# Processing Record 48 of Set 9 | vila velha
# Processing Record 49 of Set 9 | alice springs
# Processing Record 50 of Set 9 | mareeba
# Processing Record 1 of Set 10 | seoul
# Processing Record 2 of Set 10 | berea
# Processing Record 3 of Set 10 | mishan
# Processing Record 4 of Set 10 | buchanan
# Processing Record 5 of Set 10 | mudhol
# Processing Record 6 of Set 10 | tumpat
# Processing Record 7 of Set 10 | valencia
# Processing Record 8 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 9 of Set 10 | shimoda
# Processing Record 10 of Set 10 | lavrentiya
# Processing Record 11 of Set 10 | skjervoy
# Processing Record 12 of Set 10 | berlevag
# Processing Record 13 of Set 10 | morondava
# Processing Record 14 of Set 10 | sitio novo do tocantins
# Processing Record 15 of Set 10 | khalkhal
# Processing Record 16 of Set 10 | kudahuvadhoo
# Processing Record 17 of Set 10 | puerto escondido
# Processing Record 18 of Set 10 | betare oya
# Processing Record 19 of Set 10 | lethem
# Processing Record 20 of Set 10 | isiro
# Processing Record 21 of Set 10 | pishin
# Processing Record 22 of Set 10 | lucapa
# Processing Record 23 of Set 10 | padang
# Processing Record 24 of Set 10 | dubovka
# Processing Record 25 of Set 10 | bima
# Processing Record 26 of Set 10 | husavik
# Processing Record 27 of Set 10 | sinjah
# City not found. Skipping...
# Processing Record 28 of Set 10 | saint-joseph
# Processing Record 29 of Set 10 | praia da vitoria
# Processing Record 30 of Set 10 | zakamensk
# Processing Record 31 of Set 10 | newport
# Processing Record 32 of Set 10 | aksarka
# Processing Record 33 of Set 10 | mugur-aksy
# Processing Record 34 of Set 10 | aklavik
# Processing Record 35 of Set 10 | remanso
# Processing Record 36 of Set 10 | nouadhibou
# Processing Record 37 of Set 10 | champerico
# Processing Record 38 of Set 10 | kholtoson
# Processing Record 39 of Set 10 | the valley
# Processing Record 40 of Set 10 | ketchikan
# Processing Record 41 of Set 10 | kaohsiung
# Processing Record 42 of Set 10 | myitkyina
# Processing Record 43 of Set 10 | pitimbu
# Processing Record 44 of Set 10 | sao filipe
# Processing Record 45 of Set 10 | xiuyan
# Processing Record 46 of Set 10 | lake havasu city
# Processing Record 47 of Set 10 | salon-de-provence
# Processing Record 48 of Set 10 | lagoa
# Processing Record 49 of Set 10 | mundybash
# Processing Record 50 of Set 10 | charters towers
# Processing Record 1 of Set 11 | linxia
# Processing Record 2 of Set 11 | olafsvik
# Processing Record 3 of Set 11 | calvinia
# Processing Record 4 of Set 11 | umm lajj
# Processing Record 5 of Set 11 | joao camara
# Processing Record 6 of Set 11 | saint anthony
# Processing Record 7 of Set 11 | huanren
# Processing Record 8 of Set 11 | muskegon
# Processing Record 9 of Set 11 | wattegama
# Processing Record 10 of Set 11 | zhuhai
# Processing Record 11 of Set 11 | posse
# Processing Record 12 of Set 11 | huarmey
# Processing Record 13 of Set 11 | tommot
# Processing Record 14 of Set 11 | muravlenko
# Processing Record 15 of Set 11 | hofn
# Processing Record 16 of Set 11 | port lincoln
# Processing Record 17 of Set 11 | rumoi
# Processing Record 18 of Set 11 | trelew
# Processing Record 19 of Set 11 | ukiah
# Processing Record 20 of Set 11 | sitka
# Processing Record 21 of Set 11 | bandrele
# Processing Record 22 of Set 11 | ewo
# Processing Record 23 of Set 11 | teahupoo
# Processing Record 24 of Set 11 | tasbuget
# City not found. Skipping...
# Processing Record 25 of Set 11 | san quintin
# Processing Record 26 of Set 11 | fairbanks
# Processing Record 27 of Set 11 | boyolangu
# Processing Record 28 of Set 11 | hobyo
# Processing Record 29 of Set 11 | daru
# Processing Record 30 of Set 11 | oktyabrskiy
# Processing Record 31 of Set 11 | arlit
# Processing Record 32 of Set 11 | sinnamary
# Processing Record 33 of Set 11 | rio grande
# Processing Record 34 of Set 11 | livingston
# Processing Record 35 of Set 11 | roebourne
# Processing Record 36 of Set 11 | taltal
# Processing Record 37 of Set 11 | ponta delgada
# Processing Record 38 of Set 11 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 11 | santa maria
# Processing Record 40 of Set 11 | sneek
# Processing Record 41 of Set 11 | namatanai
# Processing Record 42 of Set 11 | venado tuerto
# Processing Record 43 of Set 11 | west lafayette
# Processing Record 44 of Set 11 | villa juarez
# Processing Record 45 of Set 11 | katsuura
# Processing Record 46 of Set 11 | sao mateus
# Processing Record 47 of Set 11 | zeya
# Processing Record 48 of Set 11 | bilma
# Processing Record 49 of Set 11 | marystown
# Processing Record 50 of Set 11 | belyy
# Processing Record 1 of Set 12 | nyrob
# Processing Record 2 of Set 12 | high prairie
# Processing Record 3 of Set 12 | diu
# Processing Record 4 of Set 12 | torata
# Processing Record 5 of Set 12 | lugoba
# Processing Record 6 of Set 12 | rudsar
# Processing Record 7 of Set 12 | ilhabela
# Processing Record 8 of Set 12 | karratha
# Processing Record 9 of Set 12 | dujuma
# City not found. Skipping...
# Processing Record 10 of Set 12 | comodoro rivadavia
# Processing Record 11 of Set 12 | upata
# Processing Record 12 of Set 12 | maniitsoq
# Processing Record 13 of Set 12 | tomatlan
# Processing Record 14 of Set 12 | noumea
# Processing Record 15 of Set 12 | yerbogachen
# Processing Record 16 of Set 12 | rundu
# Processing Record 17 of Set 12 | waipawa
# Processing Record 18 of Set 12 | vila do maio
# Processing Record 19 of Set 12 | marzuq
# Processing Record 20 of Set 12 | topolobampo
# Processing Record 21 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 22 of Set 12 | lorengau
# Processing Record 23 of Set 12 | kadhan
# Processing Record 24 of Set 12 | ambilobe
# Processing Record 25 of Set 12 | colares
# Processing Record 26 of Set 12 | revelstoke
# Processing Record 27 of Set 12 | kangaatsiaq
# Processing Record 28 of Set 12 | mendahara
# City not found. Skipping...
# Processing Record 29 of Set 12 | coronado
# Processing Record 30 of Set 12 | jinchang
# Processing Record 31 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 12 | jaru
# Processing Record 33 of Set 12 | morgan city
# Processing Record 34 of Set 12 | dunedin
# Processing Record 35 of Set 12 | baijiantan
# Processing Record 36 of Set 12 | tahta
# Processing Record 37 of Set 12 | kasongo-lunda
# Processing Record 38 of Set 12 | arona
# Processing Record 39 of Set 12 | chokwe
# Processing Record 40 of Set 12 | general roca
# Processing Record 41 of Set 12 | matagami
# Processing Record 42 of Set 12 | uppsala
# Processing Record 43 of Set 12 | wheeling
# Processing Record 44 of Set 12 | hovd
# Processing Record 45 of Set 12 | kristiansund
# Processing Record 46 of Set 12 | kedrovyy
# Processing Record 47 of Set 12 | pimentel
# Processing Record 48 of Set 12 | havoysund
# Processing Record 49 of Set 12 | vikhorevka
# Processing Record 50 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 1 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 13 | mahibadhoo
# Processing Record 3 of Set 13 | victor harbor
# Processing Record 4 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 5 of Set 13 | jacksonville
# Processing Record 6 of Set 13 | goderich
# Processing Record 7 of Set 13 | shar
# Processing Record 8 of Set 13 | necochea
# Processing Record 9 of Set 13 | la ronge
# Processing Record 10 of Set 13 | sipe sipe
# Processing Record 11 of Set 13 | formoso do araguaia
# City not found. Skipping...
# Processing Record 12 of Set 13 | yangambi
# Processing Record 13 of Set 13 | mana
# Processing Record 14 of Set 13 | harper
# Processing Record 15 of Set 13 | sudak
# Processing Record 16 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 17 of Set 13 | sunbury
# Processing Record 18 of Set 13 | natchez
# Processing Record 19 of Set 13 | deer lake
# Processing Record 20 of Set 13 | great yarmouth
# Processing Record 21 of Set 13 | sawtell
# Processing Record 22 of Set 13 | lakatoro
# Processing Record 23 of Set 13 | toba
# Processing Record 24 of Set 13 | tambul
# City not found. Skipping...
# Processing Record 25 of Set 13 | alampur
# Processing Record 26 of Set 13 | gornyak
# Processing Record 27 of Set 13 | birin
# Processing Record 28 of Set 13 | tilichiki
# Processing Record 29 of Set 13 | zhuanghe
# Processing Record 30 of Set 13 | esmeraldas
# Processing Record 31 of Set 13 | mikhaylov
# Processing Record 32 of Set 13 | opobo
# City not found. Skipping...
# Processing Record 33 of Set 13 | synya
# Processing Record 34 of Set 13 | bonnyville
# Processing Record 35 of Set 13 | tokur
# Processing Record 36 of Set 13 | botwood
# Processing Record 37 of Set 13 | bilibino
# Processing Record 38 of Set 13 | naze
# Processing Record 39 of Set 13 | fort smith
# Processing Record 40 of Set 13 | ust-tsilma
# Processing Record 41 of Set 13 | sangar
# Processing Record 42 of Set 13 | fort nelson
# Processing Record 43 of Set 13 | alofi
# Processing Record 44 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 13 | dali
# Processing Record 46 of Set 13 | gedo
# Processing Record 47 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 48 of Set 13 | mandan
# Processing Record 49 of Set 13 | balclutha
# Processing Record 50 of Set 13 | boa vista
# Processing Record 1 of Set 14 | forbes
# Processing Record 2 of Set 14 | qaqortoq
# Processing Record 3 of Set 14 | kiskunmajsa
# Processing Record 4 of Set 14 | artyom
# Processing Record 5 of Set 14 | serebryanyy bor
# Processing Record 6 of Set 14 | changji
# Processing Record 7 of Set 14 | ruidoso
# Processing Record 8 of Set 14 | presidencia roque saenz pena
# Processing Record 9 of Set 14 | los llanos de aridane
# Processing Record 10 of Set 14 | tlapa
# City not found. Skipping...
# Processing Record 11 of Set 14 | mineral wells
# Processing Record 12 of Set 14 | severo-yeniseyskiy
# Processing Record 13 of Set 14 | vardo
# Processing Record 14 of Set 14 | duldurga
# Processing Record 15 of Set 14 | baiyin
# Processing Record 16 of Set 14 | tuni
# Processing Record 17 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 18 of Set 14 | agalatovo
# Processing Record 19 of Set 14 | komsomolskiy
# Processing Record 20 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 14 | banjar
# Processing Record 22 of Set 14 | liverpool
# Processing Record 23 of Set 14 | jiddah
# City not found. Skipping...
# Processing Record 24 of Set 14 | itarema
# Processing Record 25 of Set 14 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 14 | bambanglipuro
# Processing Record 27 of Set 14 | shache
# Processing Record 28 of Set 14 | nantucket
# Processing Record 29 of Set 14 | juneau
# Processing Record 30 of Set 14 | kyzyl-suu
# Processing Record 31 of Set 14 | labrea
# Processing Record 32 of Set 14 | esterhazy
# Processing Record 33 of Set 14 | saraland
# Processing Record 34 of Set 14 | pryyutivka
# Processing Record 35 of Set 14 | liku
# Processing Record 36 of Set 14 | nampula
# Processing Record 37 of Set 14 | kokopo
# Processing Record 38 of Set 14 | thinadhoo
# Processing Record 39 of Set 14 | gebre guracha
# Processing Record 40 of Set 14 | karagaylinskiy
# Processing Record 41 of Set 14 | la peca
# Processing Record 42 of Set 14 | portobelo
# Processing Record 43 of Set 14 | sechura
# Processing Record 44 of Set 14 | polson
# Processing Record 45 of Set 14 | houston
# Processing Record 46 of Set 14 | batagay-alyta
# Processing Record 47 of Set 14 | warrnambool
# Processing Record 48 of Set 14 | iberia
# Processing Record 49 of Set 14 | bakal
# Processing Record 50 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 1 of Set 15 | imeni poliny osipenko
# Processing Record 2 of Set 15 | alexandria
# Processing Record 3 of Set 15 | alice
# Processing Record 4 of Set 15 | vila franca do campo
# Processing Record 5 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 6 of Set 15 | channel-port aux basques
# Processing Record 7 of Set 15 | phrai bung
# City not found. Skipping...
# Processing Record 8 of Set 15 | port-gentil
# Processing Record 9 of Set 15 | abbeville
# Processing Record 10 of Set 15 | valparaiso
# Processing Record 11 of Set 15 | shubarkuduk
# Processing Record 12 of Set 15 | imbituba
# Processing Record 13 of Set 15 | a
# City not found. Skipping...
# Processing Record 14 of Set 15 | ciudad valles
# Processing Record 15 of Set 15 | shimanovsk
# Processing Record 16 of Set 15 | sesheke
# Processing Record 17 of Set 15 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 15 | pacific grove
# Processing Record 19 of Set 15 | port shepstone
# Processing Record 20 of Set 15 | aquidauana
# Processing Record 21 of Set 15 | alanya
# Processing Record 22 of Set 15 | kogon
# Processing Record 23 of Set 15 | neftcala
# Processing Record 24 of Set 15 | vanavara
# Processing Record 25 of Set 15 | cam ranh
# Processing Record 26 of Set 15 | christchurch
# Processing Record 27 of Set 15 | manokwari
# Processing Record 28 of Set 15 | aksu
# Processing Record 29 of Set 15 | maamba
# Processing Record 30 of Set 15 | abeche
# Processing Record 31 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 15 | jabiru
# City not found. Skipping...
# Processing Record 33 of Set 15 | oudtshoorn
# Processing Record 34 of Set 15 | hami
# Processing Record 35 of Set 15 | bielsko-biala
# Processing Record 36 of Set 15 | vestmannaeyjar
# Processing Record 37 of Set 15 | torrijos
# Processing Record 38 of Set 15 | lamu
# Processing Record 39 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 15 | mount isa
# Processing Record 41 of Set 15 | manadhoo
# Processing Record 42 of Set 15 | hegang
# Processing Record 43 of Set 15 | kununurra
# Processing Record 44 of Set 15 | serenje
# Processing Record 45 of Set 15 | santa isabel
# Processing Record 46 of Set 15 | srednekolymsk
# Processing Record 47 of Set 15 | port-cartier
# Processing Record 48 of Set 15 | kenai
# Processing Record 49 of Set 15 | puerto pailas
# Processing Record 50 of Set 15 | hokitika
# Processing Record 1 of Set 16 | miguel hidalgo
# Processing Record 2 of Set 16 | mezen
# Processing Record 3 of Set 16 | pavino
# Processing Record 4 of Set 16 | cayenne
# Processing Record 5 of Set 16 | marawi
# Processing Record 6 of Set 16 | horsham
# Processing Record 7 of Set 16 | maraba
# Processing Record 8 of Set 16 | san lorenzo
# Processing Record 9 of Set 16 | mirnyy
# Processing Record 10 of Set 16 | burnie
# Processing Record 11 of Set 16 | cozumel
# Processing Record 12 of Set 16 | nuevo progreso
# Processing Record 13 of Set 16 | flin flon
# Processing Record 14 of Set 16 | mbandaka
# Processing Record 15 of Set 16 | kindia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0            Gamba      GA  -2.6500  10.0000     74.97        96         100
# 1     San Patricio      US  28.0170 -97.5169     84.92        85           2
# 2          Ushuaia      AR -54.8000 -68.3000     42.46        65          40
# 3        Cape Town      ZA -33.9258  18.4232     68.34        34           2
# 4      Zhanakorgan      KZ  43.9098  67.2495     78.84        43           0
# 5           Waddan      LY  29.1614  16.1390     76.48        25           0
# 6  Arraial Do Cabo      BR -22.9661 -42.0278     72.97        88          69
# 7     Punta Arenas      CL -53.1500 -70.9167     35.71        87           0
# 8         Altamira      BR  -3.2033 -52.2064     76.57        84         100
# 9             Lebu      CL -37.6167 -73.6500     47.52        83          93
#
#    Wind Speed Current Description
# 0        5.73     overcast clouds
# 1       14.09           clear sky
# 2       20.71    scattered clouds
# 3       15.37           clear sky
# 4        4.29           clear sky
# 5        9.46           clear sky
# 6       14.61       broken clouds
# 7       11.18           clear sky
# 8        2.04     overcast clouds
# 9        6.87     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
